ping statistics ---
4 packets transmitted, 4 packets received, 0.0% packet loss
round-trip min/avg/max/stddev = 257.450/291.974/335.366/28.757 ms
(base) tangzongkai@KanedeAir ~ % ping -c 4 speedtest.uztelecom.uz  
PING speedtest.uztelecom.uz (195.69.189.215): 56 data bytes
64 bytes from 195.69.189.215: icmp_seq=0 ttl=53 time=305.563 ms
64 bytes from 195.69.189.215: icmp_seq=1 ttl=53 time=325.408 ms
64 bytes from 195.69.189.215: icmp_seq=2 ttl=53 time=343.788 ms
64 bytes from 195.69.189.215: icmp_seq=3 ttl=53 time=260.969 ms

--- speedtest.uztelecom.uz ping statistics ---
4 packets transmitted, 4 packets received, 0.0% packet loss
round-trip min/avg/max/stddev = 260.969/308.932/343.788/30.815 ms
(base) tangzongkai@KanedeAir ~ % ping -c 4 speedtest.uztelecom.uz
PING speedtest.uztelecom.uz (195.69.189.215): 56 data bytes
64 bytes from 195.69.189.215: icmp_seq=0 ttl=53 time=269.921 ms
64 bytes from 195.69.189.215: icmp_seq=1 ttl=53 time=287.879 ms
64 bytes from 195.69.189.215: icmp_seq=2 ttl=53 time=307.708 ms
64 bytes from 195.69.189.215: icmp_seq=3 ttl=53 time=325.374 ms

--- speedtest.uztelecom.uz ping statistics ---
4 packets transmitted, 4 packets received, 0.0% packet loss
round-trip min/avg/max/stddev = 269.921/297.721/325.374/20.821 ms
(base) tangzongkai@KanedeAir ~ % ping -c 4 speedtest.uztelecom.uz
PING speedtest.uztelecom.uz (195.69.189.215): 56 data bytes
64 bytes from 195.69.189.215: icmp_seq=0 ttl=53 time=289.730 ms
64 bytes from 195.69.189.215: icmp_seq=1 ttl=53 time=308.458 ms
64 bytes from 195.69.189.215: icmp_seq=2 ttl=53 time=327.978 ms
64 bytes from 195.69.189.215: icmp_seq=3 ttl=53 time=345.906 ms

--- speedtest.uztelecom.uz ping statistics ---
4 packets transmitted, 4 packets received, 0.0% packet loss
round-trip min/avg/max/stddev = 289.730/318.018/345.906/21.027 ms
(base) tangzongkai@KanedeAir ~ % 
"""
pattern = r"time=(\d+\.\d+) ms"

matches = re.findall(pattern, data)
print(matches)
ping = {}
for a in address:
    temp = []
    for _ in range(12):
        temp.append(float(matches.pop(0)))
    ping[a] = temp
print(ping)
# Out:
# ['201.376', '202.299', '202.016', '204.453', '200.708', '201.803', '203.930', '202.561', '203.603', '203.624', '202.327', '203.547', '314.487', '324.830', '342.706', '260.032', '349.424', '264.671', '284.455', '302.382', '305.037', '322.467', '343.514', '258.676', '426.068', '443.011', '463.638', '380.528', '364.710', '429.746', '452.467', '471.579', '421.010', '438.258', '458.585', '374.948', '353.357', '374.264', '383.511', '403.301', '414.151', '433.935', '350.112', '330.054', '416.319', '434.356', '352.744', '372.540', '248.561', '298.565', '317.086', '336.555', '320.899', '339.584', '254.881', '274.790', '262.685', '284.501', '303.377', '321.906', '107.499', '105.187', '106.890', '106.568', '107.074', '106.501', '104.623', '105.397', '103.923', '105.753', '106.753', '106.156', '440.526', '356.090', '375.237', '393.546', '354.747', '379.318', '391.689', '411.481', '354.111', '348.011', '390.870', '409.638', '288.326', '308.211', '325.733', '345.620', '344.188', '262.733', '281.17
# ...

# %%
import statistics
result = {}
for a in address:
    ping_delays = ping[a]
    mean = statistics.mean(ping_delays)
    stdev = statistics.stdev(ping_delays)
    result[a] = [mean, stdev]
print(result)
# Out:
# {'iperf.he.net': [202.68725, 1.1395097929293199], 'bouygues.testdebit.info': [306.05674999999997, 32.859071638313495], 'iperf.astra.in.ua': [427.04566666666665, 35.868790037968644], 'ping-90ms.online.net': [384.887, 35.09309406033148], 'ping.online.net': [296.94916666666666, 31.570085189602956], 'iperf.biznetnetworks.com': [106.027, 1.072145003761574], 'sp11.wom.cl': [383.772, 28.165902748471662], 'lg.rltx.net': [303.98525, 31.63003264483988], 'lille.testdebit.info': [298.27191666666664, 29.4524530679483], 'speedtest.uztelecom.uz': [308.2235, 27.182661447393937]}

# %%
import matplotlib.pyplot as plt
distance = [12677.105, 16790.863, 15236.508, 16788.766, 16788.766, 5210.904, 14252.440, 16440.268, 16790.863, 11669.678]
delay  = [result[key][0] for key in result]
jitter = [result[key][1] for key in result]
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 8))

ax1.scatter(distance, delay, label = 'Delay', color='b')
ax1.set_xlabel('Distance')
ax1.set_ylabel('Average Round-Trip Delay')
ax1.set_title('Average Round-Trip Delay and Distance')
ax1.legend()

ax2.scatter(distance, jitter, label = 'Jitter', color='r')
ax2.set_xlabel('Distance')
ax2.set_ylabel('Jitter')
ax2.set_title('Jitter and Distance')
ax2.legend()

plt.tight_layout()
plt.show()

# %%
import subprocess
import re

address = ['iperf.he.net', 'bouygues.testdebit.info', 'iperf.astra.in.ua', 'ping-90ms.online.net', 
           'ping.online.net', 'iperf.biznetnetworks.com', 'sp11.wom.cl', 'lg.rltx.net',
          'lille.testdebit.info', 'speedtest.uztelecom.uz']

bandwith_result = {}
for a in address:
    bw = []
    for _ in range(3):
        try:
            result = subprocess.run(["iperf", "-c", a], capture_output=True, text=True)
            output = result.stdout

            bandwidth_match = re.search(r"(\d+\.\d+)\s+Mbits/sec", output)
            if bandwidth_match:
                bandwidth = float(bandwidth_match.group(1))
                bw.append(bandwidth)
            else:
                print(a, "No result")
        except Exception as e:
            print("Error:", e)
    bandwith_result[a] = bw
# Out:
# iperf.astra.in.ua No result
# iperf.astra.in.ua No result
# iperf.astra.in.ua No result
# iperf.biznetnetworks.com No result
# iperf.biznetnetworks.com No result
# iperf.biznetnetworks.com No result
# sp11.wom.cl No result
# sp11.wom.cl No result
# sp11.wom.cl No result
# lg.rltx.net No result
# lg.rltx.net No result
# lg.rltx.net No result
# lille.testdebit.info No result
# speedtest.uztelecom.uz No result
# speedtest.uztelecom.uz No result
# speedtest.uztelecom.uz No result

# %%
bw = []
for _ in range(3):
    try:
        result = subprocess.run(["iperf", "-c", "iperf.astra.in.ua", "-p", "443"], capture_output=True, text=True)
        output = result.stdout

        bandwidth_match = re.search(r"(\d+\.\d+)\s+Mbits/sec", output)
        if bandwidth_match:
            bandwidth = float(bandwidth_match.group(1))
            bw.append(bandwidth)
        else:
            print(a, "No result")
    except Exception as e:
        print("Error:", e)
bandwith_result["iperf.astra.in.ua"] = bw

# %%
bw = []
for _ in range(3):
    try:
        result = subprocess.run(["iperf", "-c", "iperf.biznetnetworks.com", "-p", "443"], capture_output=True, text=True)
        output = result.stdout

        bandwidth_match = re.search(r"(\d+\.\d+)\s+Mbits/sec", output)
        if bandwidth_match:
            bandwidth = float(bandwidth_match.group(1))
            bw.append(bandwidth)
        else:
            print(a, "No result")
    except Exception as e:
        print("Error:", e)
bandwith_result["iperf.biznetnetworks.com"] = bw

# %%
bw = []
for _ in range(3):
    try:
        result = subprocess.run(["iperf", "-c", "sp11.wom.cl", "-p", "443"], capture_output=True, text=True)
        output = result.stdout

        bandwidth_match = re.search(r"(\d+\.\d+)\s+Mbits/sec", output)
        if bandwidth_match:
            bandwidth = float(bandwidth_match.group(1))
            bw.append(bandwidth)
        else:
            print(a, "No result")
    except Exception as e:
        print("Error:", e)
bandwith_result["sp11.wom.cl"] = bw

# %%
bw = []
for _ in range(3):
    try:
        result = subprocess.run(["iperf", "-c", "lg.rltx.net", "-p", "443"], capture_output=True, text=True)
        output = result.stdout

        bandwidth_match = re.search(r"(\d+\.\d+)\s+Mbits/sec", output)
        if bandwidth_match:
            bandwidth = float(bandwidth_match.group(1))
            bw.append(bandwidth)
        else:
            print(a, "No result")
    except Exception as e:
        print("Error:", e)
bandwith_result["lg.rltx.net"] = bw

# %%
bandwith_result
# Out:
# {'iperf.he.net': [2.75, 2.72, 2.54], 'bouygues.testdebit.info': [1.71, 1.7, 1.71], 'iperf.astra.in.ua': [4.0995264711810995, 4.773561933091558, 5.0406191730904375], 'ping-90ms.online.net': [5.85, 6.74, 5.25], 'ping.online.net': [2.09, 2.31, 2.22], 'iperf.biznetnetworks.com': [5.03, 5.03, 5.01], 'sp11.wom.cl': [1.28, 1.22, 1.32], 'lg.rltx.net': [2.71, 2.71, 2.86], 'lille.testdebit.info': [1.71, 1.71], 'speedtest.uztelecom.uz': []}

# %%
bw = []
for _ in range(3):
    try:
        result = subprocess.run(["iperf", "-c", 'lille.testdebit.info'], capture_output=True, text=True)
        output = result.stdout

        bandwidth_match = re.search(r"(\d+\.\d+)\s+Mbits/sec", output)
        if bandwidth_match:
            bandwidth = float(bandwidth_match.group(1))
            bw.append(bandwidth)
        else:
            print(a, "No result")
    except Exception as e:
        print("Error:", e)
bandwith_result["sp11.wom.cl"] = bw

# %%
bw = []
for _ in range(3):
    try:
        result = subprocess.run(["iperf", "-c", "speedtest.uztelecom.uz", "-p", "443"], capture_output=True, text=True)
        output = result.stdout

        bandwidth_match = re.search(r"(\d+\.\d+)\s+Mbits/sec", output)
        if bandwidth_match:
            bandwidth = float(bandwidth_match.group(1))
            bw.append(bandwidth)
        else:
            print(a, "No result")
    except Exception as e:
        print("Error:", e)
bandwith_result["speedtest.uztelecom.uz"] = bw

# %%
bandwith_result
# Out:
# {'iperf.he.net': [2.75, 2.72, 2.54],
#  'bouygues.testdebit.info': [1.71, 1.7, 1.71],
#  'iperf.astra.in.ua': [3.05, 2.24, 2.79],
#  'ping-90ms.online.net': [5.85, 6.74, 5.25],
#  'ping.online.net': [2.09, 2.31, 2.22],
#  'iperf.biznetnetworks.com': [5.03, 5.03, 5.01],
#  'sp11.wom.cl': [2.04, 2.14, 1.72],
#  'lg.rltx.net': [2.71, 2.71, 2.86],
#  'lille.testdebit.info': [1.71, 1.71],
#  'speedtest.uztelecom.uz': [2.38, 2.66, 2.38]}

# %%
average_bandwidths = {}

for site, bandwidths in bandwith_result.items():
    average_bandwidth = sum(bandwidths) / len(bandwidths)
    average_bandwidths[site] = average_bandwidth
average_bandwidths
# Out:
# {'iperf.he.net': 2.6700000000000004,
#  'bouygues.testdebit.info': 1.7066666666666668,
#  'iperf.astra.in.ua': 2.6933333333333334,
#  'ping-90ms.online.net': 5.946666666666666,
#  'ping.online.net': 2.206666666666667,
#  'iperf.biznetnetworks.com': 5.023333333333333,
#  'sp11.wom.cl': 1.9666666666666666,
#  'lg.rltx.net': 2.76,
#  'lille.testdebit.info': 1.71,
#  'speedtest.uztelecom.uz': 2.473333333333333}

# %%
import datetime
import subprocess
furthest = 'lille.testdebit.info'
closest = 'iperf.biznetnetworks.com'
result = subprocess.run(["iperf", "-c", furthest, "-p", "80"], capture_output=True, text=True)
output1 = result.stdout
result = subprocess.run(["iperf", "-c", closest, "-p", "443"], capture_output=True, text=True)
output2 = result.stdout
current_time = datetime.datetime.now()

# %%
print(current_time)
print(output1)
print(output2)
# Out:
# 2023-09-14 18:03:50.855699
# ------------------------------------------------------------
# Client connecting to lille.testdebit.info, TCP port 80
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 50213 connected with 89.84.1.234 port 80 (icwnd/mss/irtt=14/1448/244000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-10.09 sec  5.00 MBytes  4.16 Mbits/sec
#
# ------------------------------------------------------------
# Client connecting to iperf.biznetnetworks.com, TCP port 443
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 50214 connected with 117.102.109.186 port 443 (icwnd/mss/irtt=14/1448/102000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-0.21 sec   128 KBytes  4.99 Mbits/sec

# %%
print(current_time)
print(output1)
print(output2)
# Out:
# 2023-09-14 23:17:30.151747
# ------------------------------------------------------------
# Client connecting to lille.testdebit.info, TCP port 80
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 51500 connected with 89.84.1.234 port 80 (icwnd/mss/irtt=14/1448/303000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-10.44 sec  2.75 MBytes  2.21 Mbits/sec
#
# ------------------------------------------------------------
# Client connecting to iperf.biznetnetworks.com, TCP port 443
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 51501 connected with 117.102.109.186 port 443 (icwnd/mss/irtt=14/1448/103000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-0.21 sec   128 KBytes  5.02 Mbits/sec

# %%
print(current_time)
print(output1)
print(output2)
# Out:
# 2023-09-14 10:00:30.185886
# ------------------------------------------------------------
# Client connecting to lille.testdebit.info, TCP port 80
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 49496 connected with 89.84.1.234 port 80 (icwnd/mss/irtt=14/1448/303000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-10.24 sec  3.63 MBytes  2.97 Mbits/sec
#
# ------------------------------------------------------------
# Client connecting to iperf.biznetnetworks.com, TCP port 443
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 49499 connected with 117.102.109.186 port 443 (icwnd/mss/irtt=14/1448/171000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-0.24 sec   128 KBytes  4.37 Mbits/sec

# %%
print(current_time)
print(output1)
print(output2)
# Out:
# 2023-09-14 13:01:21.327040
# ------------------------------------------------------------
# Client connecting to lille.testdebit.info, TCP port 80
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 49548 connected with 89.84.1.234 port 80 (icwnd/mss/irtt=14/1448/303000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-10.14 sec  3.50 MBytes  2.90 Mbits/sec
#
# ------------------------------------------------------------
# Client connecting to iperf.biznetnetworks.com, TCP port 443
# TCP window size:  128 KByte (default)
# ------------------------------------------------------------
# [  1] local 192.168.50.79 port 49551 connected with 117.102.109.186 port 443 (icwnd/mss/irtt=14/1448/177000)
# [ ID] Interval       Transfer     Bandwidth
# [  1] 0.00-0.22 sec   128 KBytes  4.74 Mbits/sec

# %%
import matplotlib.pyplot as plt
address = ['iperf.he.net', 'bouygues.testdebit.info', 'iperf.astra.in.ua', 'ping-90ms.online.net', 
           'ping.online.net', 'iperf.biznetnetworks.com', 'sp11.wom.cl', 'lg.rltx.net',
          'lille.testdebit.info', 'speedtest.uztelecom.uz']

average_bandwidth = {'iperf.he.net': 2.6700000000000004,
 'bouygues.testdebit.info': 1.7066666666666668,
 'iperf.astra.in.ua': 2.6933333333333334,
 'ping-90ms.online.net': 5.946666666666666,
 'ping.online.net': 2.206666666666667,
 'iperf.biznetnetworks.com': 5.023333333333333,
 'sp11.wom.cl': 1.9666666666666666,
 'lg.rltx.net': 2.76,
 'lille.testdebit.info': 1.71,
 'speedtest.uztelecom.uz': 2.473333333333333}

delay = {'iperf.he.net': [202.68725, 1.1395097929293199], 'bouygues.testdebit.info': [306.05674999999997, 32.859071638313495], 'iperf.astra.in.ua': [427.04566666666665, 35.868790037968644], 'ping-90ms.online.net': [384.887, 35.09309406033148], 'ping.online.net': [296.94916666666666, 31.570085189602956], 'iperf.biznetnetworks.com': [106.027, 1.072145003761574], 'sp11.wom.cl': [383.772, 28.165902748471662], 'lg.rltx.net': [303.98525, 31.63003264483988], 'lille.testdebit.info': [298.27191666666664, 29.4524530679483], 'speedtest.uztelecom.uz': [308.2235, 27.182661447393937]}

product = {}
for a in address:
    product[a] = average_bandwidth[a]*delay[a][0]
addresses = list(product.keys())
values = list(product.values())
plt.figure(figsize=(15, 8)) 
plt.bar(addresses, values, color='blue')
plt.xlabel('Address')
plt.ylabel('Bandwidth-Delay Product') 
plt.title('Bandwidth-Delay Product for Different Addresses') 
plt.xticks(rotation=45, ha='right') 
plt.tight_layout() 


plt.show()

# %%
hop_counts = [11, 14, 11, 13, 13, 11, 19, 12, 15, 13]
plt.figure(figsize=(10, 6)) 
plt.scatter(hop_counts, values, color='red')
plt.xlabel('Hop Counts') 
plt.ylabel('Bandwidth-Delay Product')
plt.title('Bandwidth-Delay Product vs. Hop Counts') 


plt.show()
